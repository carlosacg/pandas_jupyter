# %% [markdown]
# Este código muestra los siguientes puntos:
# 1. País que más productos consume.
# 2. Los productos más vendidos y los más populares en
# términos de gananciasyo cantidad de ventas
# 3. Gráfico de tendencia
# 4. Gráfico de correlación entre el precio y la cantidad de ventas..

# %%
import pandas as pd
from utils import get_max_country, get_most_sold_products, get_trend, get_correlation

file_path = "online_retail_II.xlsx"
df = pd.read_excel(file_path)

get_max_country(df)
get_most_sold_products(df)
get_trend(df)
get_correlation(df)
# Out:
# The country that consumes the most products is: United Kingdom
# Total quantity of products consumed: 4429046
# The 10 most sold products in terms of quantity are:
#                              Description  Quantity  Total_Ganancias
# 4402  WHITE HANGING HEART T-LIGHT HOLDER     57733        157865.43
# 4509   WORLD WAR 2 GLIDERS ASSTD DESIGNS     54698         11310.29
# 721                  BROCADE RING PURSE      47647          8879.82
# 2744    PACK OF 72 RETRO SPOT CAKE CASES     46106         23759.26
# 279        ASSORTED COLOUR BIRD ORNAMENT     44925         72454.12
# 147          60 TEATIME FAIRY CAKE CASES     36326         18128.25
# 2742  PACK OF 60 PINK PAISLEY CAKE CASES     31822         16184.21
# 2158             JUMBO BAG RED RETROSPOT     30727         56444.61
# 3984                SMALL POPCORN HOLDER     29500         26791.95
# 4067      STRAWBERRY CERAMIC TRINKET BOX     26563         33834.70
# The 10 most popular products in terms of total sales are:
# ...
